# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn

# %%
df = pd.read_csv("advertising.csv")
x = df["TV"].to_numpy()
y = df["Sales"].to_numpy()

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.7,random_state=1)
x_train = x_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)

# %%
lr = LinearRegression()
lr_fit = lr.fit(x_train,y_train)
seaborn.regplot(x=x,y=y)
plt.xlabel("TV")
plt.ylabel("SALES")
plt.show()

# %%
coefficient = lr_fit.coef_[0]
intercept = lr_fit.intercept_
sales_val = (coefficient * 100) + intercept
sales_val
# Out:
# np.float64(12.470108835601609)

# %%
predicted_values = lr.predict(x_test)
mean_squared_error(y_test,predicted_values)
mean_absolute_error(y_test,predicted_values)
# Out:
# 1.86239036505223

# %%
# multilinear regression
x = df[["TV","Radio","Newspaper"]]
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.7,random_state=1)
multilr = LinearRegression()
multilr_fit = multilr.fit(x_train,y_train)

predicted_values = multilr.predict(x_test)
mean_squared_error(y_test,predicted_values)
mean_absolute_error(y_test,predicted_values)
# Out:
# 1.194741713405674
