# %%
import pandas as pd

df = pd.read_csv("housing.csv",header=None)
df = df[0].str.split(" ",expand=True)
for column in df:
    df[column] = df[column].str.strip()

df = df.drop(columns=[26,27,28,29,30,31])
df = df.replace("",None)
#df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       54 non-null     str
#  1   1       452 non-null    str
#  2   2       1 non-null      str
#  3   3       187 non-null    str
#  4   4       318 non-null    str
#  5   5       58 non-null     str
#  6   6       309 non-null    str
#  7   7       197 non-null    str
#  8   8       309 non-null    str
#  9   9       197 non-null    str
#  10  10      309 non-null    str
#  11  11      197 non-null    str
#  12  12      331 non-null    str
#  13  13      194 non-null    str
#  14  14      304 non-null    str
#  15  15      204 non-null    str
#  16  16      302 non-null    str
#  17  17      183 non-null    str
#  18  18      117 non-null    str
#  19  19      245 non-null    str
#  20  20      258 non-null    str
#  21  21      263 non-null    str
#  22  22      271 non-null    str
# ...
