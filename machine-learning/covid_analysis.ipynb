# %%
import pandas as pd

# %%
df = pd.read_csv("WHO-COVID-19-global-data.csv")
df
# Out:
#        DateReported Country_code      Country WHO_region  New_cases  \
# 0        2020-01-03           AF  Afghanistan       EMRO          0
# 1        2020-01-04           AF  Afghanistan       EMRO          0
# 2        2020-01-05           AF  Afghanistan       EMRO          0
# 3        2020-01-06           AF  Afghanistan       EMRO          0
# 4        2020-01-07           AF  Afghanistan       EMRO          0
# ...             ...          ...          ...        ...        ...
# 121227   2021-05-23           ZW     Zimbabwe       AFRO         15
# 121228   2021-05-24           ZW     Zimbabwe       AFRO          3
# 121229   2021-05-25           ZW     Zimbabwe       AFRO         14
# 121230   2021-05-26           ZW     Zimbabwe       AFRO         10
# 121231   2021-05-27           ZW     Zimbabwe       AFRO        113
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df["DateReported"] = pd.to_datetime(df["DateReported"])
data = df.groupby("DateReported").sum()
data
# Out:
#                                                    Country_code  \
# DateReported
# 2020-01-03    AFALDZASADAOAIAGARAMAWAUATAZBSBHBDBBBYBEBZBJBM...
# 2020-01-04    AFALDZASADAOAIAGARAMAWAUATAZBSBHBDBBBYBEBZBJBM...
# 2020-01-05    AFALDZASADAOAIAGARAMAWAUATAZBSBHBDBBBYBEBZBJBM...
# 2020-01-06    AFALDZASADAOAIAGARAMAWAUATAZBSBHBDBBBYBEBZBJBM...
# 2020-01-07    AFALDZASADAOAIAGARAMAWAUATAZBSBHBDBBBYBEBZBJBM...
# ...                                                         ...
# 2021-05-24    AFALDZASADAOAIAGARAMAWAUATAZBSBHBDBBBYBEBZBJBM...
# 2021-05-25    AFALDZASADAOAIAGARAMAWAUATAZBSBHBDBBBYBEBZBJBM...
# 2021-05-26    AFALDZASADAOAIAGARAMAWAUATAZBSBHBDBBBYBEBZBJBM...
# 2021-05-27    AFALDZASADAOAIAGARAMAWAUATAZBSBHBDBBBYBEBZBJBM...
# 2021-05-28    AFASAIAGARAWAUBSBHBDBBBZBMBTBOXABRVGBNKHCAKYCL...
#
#                                                         Country  \
# DateReported
# 2020-01-03    AfghanistanAlbaniaAlgeriaAmerican SamoaAndorra...
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go

figure = go.Figure(data=[
    go.Scatter(name="New Cases",x=data.index,y=data["New_cases"]),
    go.Scatter(name="New Deaths",x=data.index,y=data["New_deaths"])
])
figure.write_html("covid_scatter2.html")

# %%
datetime_series = df["DateReported"]
datetime_series[0].date().month
# Out:
# 1

# %%
import datetime

datetime_series[0].strftime("%d/%m/%Y")
# Out:
# '03/01/2020'
